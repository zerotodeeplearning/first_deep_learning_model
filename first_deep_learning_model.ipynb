# %% [markdown]
# # First Deep Learning Model
#
# Hello, this is our first model.

# %%
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and red crosses");

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential([
    Dense(4, input_shape=(2,), activation='tanh'),
    Dense(1, activation='sigmoid'),
])

model.compile(SGD(lr=0.5),
              'binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X, y, epochs=15)
# Out:
# Train on 1000 samples
# Epoch 1/15
# 1000/1000 [==============================] - 1s 509us/sample - loss: 0.6976 - accuracy: 0.5090
# Epoch 2/15
# 1000/1000 [==============================] - 0s 46us/sample - loss: 0.6930 - accuracy: 0.5840
# Epoch 3/15
# 1000/1000 [==============================] - 0s 51us/sample - loss: 0.6801 - accuracy: 0.5560
# Epoch 4/15
# 1000/1000 [==============================] - 0s 44us/sample - loss: 0.6514 - accuracy: 0.6430
# Epoch 5/15
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.5879 - accuracy: 0.7770
# Epoch 6/15
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.5060 - accuracy: 0.8420
# Epoch 7/15
# 1000/1000 [==============================] - 0s 47us/sample - loss: 0.4281 - accuracy: 0.8580
# Epoch 8/15
# 1000/1000 [==============================] - 0s 50us/sample - loss: 0.3569 - accuracy: 0.8730
# Epoch 9/15
# 1000/1000 [==============================] - 0s 50us/sample - loss: 0.2809 - accuracy: 0.9160
# Epoch 10/15
# 1000/1000 [==============================] - 0s 76us/sample - loss: 0.2122 - accuracy: 0.9830
# Epoch 11/15
# 1000/1000 [==============================] - 0s 68us/sample - loss: 0.1623 - accuracy: 0.9980
# Epoch 12/15
# 1000/1000 [==============================] - 0s 54us/sample - loss: 0.1290 - accuracy: 0.9990
# Epoch 13/15
# 1000/1000 [==============================] - 0s 67us/sample - loss: 0.1062 - accuracy: 0.9990
# Epoch 14/15
# 1000/1000 [==============================] - 0s 55us/sample - loss: 0.0902 - accuracy: 1.0000
# Epoch 15/15
# 1000/1000 [==============================] - 0s 57us/sample - loss: 0.0783 - accuracy: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and red crosses");
