# %% [markdown]
# # First Deep Learning Model
#
# Hello, this is our first model.

# %%
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses");

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential([
    Dense(4, input_shape=(2,), activation='tanh'),
    Dense(1, activation='sigmoid'),
])

model.compile(SGD(lr=0.5),
              'binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X, y, epochs=15)
# Out:
# Epoch 1/15
# 1000/1000 [==============================] - 0s 476us/sample - loss: 0.6695 - accuracy: 0.6390
# Epoch 2/15
# 1000/1000 [==============================] - 0s 204us/sample - loss: 0.5831 - accuracy: 0.7710
# Epoch 3/15
# 1000/1000 [==============================] - 0s 142us/sample - loss: 0.4596 - accuracy: 0.9460
# Epoch 4/15
# 1000/1000 [==============================] - 0s 119us/sample - loss: 0.3367 - accuracy: 0.9970
# Epoch 5/15
# 1000/1000 [==============================] - 0s 89us/sample - loss: 0.2437 - accuracy: 1.0000
# Epoch 6/15
# 1000/1000 [==============================] - 0s 108us/sample - loss: 0.1842 - accuracy: 1.0000
# Epoch 7/15
# 1000/1000 [==============================] - 0s 453us/sample - loss: 0.1456 - accuracy: 1.0000
# Epoch 8/15
# 1000/1000 [==============================] - 0s 278us/sample - loss: 0.1191 - accuracy: 1.0000
# Epoch 9/15
# 1000/1000 [==============================] - 0s 272us/sample - loss: 0.1000 - accuracy: 1.0000
# Epoch 10/15
# 1000/1000 [==============================] - 0s 203us/sample - loss: 0.0861 - accuracy: 1.0000
# Epoch 11/15
# 1000/1000 [==============================] - 0s 137us/sample - loss: 0.0754 - accuracy: 1.0000
# Epoch 12/15
# 1000/1000 [==============================] - 0s 239us/sample - loss: 0.0668 - accuracy: 1.0000
# Epoch 13/15
# 1000/1000 [==============================] - 0s 89us/sample - loss: 0.0602 - accuracy: 1.0000
# Epoch 14/15
# 1000/1000 [==============================] - 0s 129us/sample - loss: 0.0546 - accuracy: 1.0000
# Epoch 15/15
# 1000/1000 [==============================] - 0s 128us/sample - loss: 0.0500 - accuracy: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses");
